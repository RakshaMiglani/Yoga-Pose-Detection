# %%
import mediapipe as mp
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torch_geometric.data import Data
from scipy.spatial import Delaunay
import os 
import cv2
import pandas as pd
import ast

# %%
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# %%
def create_graph(image_path, label):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pose.process(image_rgb)
    if not results.pose_landmarks:
        return None
    landmarks = results.pose_landmarks.landmark
    nodes = []
    for landmark in landmarks:
        nodes.append([landmark.x, landmark.y, landmark.z])
    x = torch.tensor(nodes, dtype=torch.float)
    edges = [
        (mp_pose.PoseLandmark.LEFT_SHOULDER.value, mp_pose.PoseLandmark.LEFT_ELBOW.value),
        (mp_pose.PoseLandmark.LEFT_ELBOW.value, mp_pose.PoseLandmark.LEFT_WRIST.value),
        (mp_pose.PoseLandmark.RIGHT_SHOULDER.value, mp_pose.PoseLandmark.RIGHT_ELBOW.value),
        (mp_pose.PoseLandmark.RIGHT_ELBOW.value, mp_pose.PoseLandmark.RIGHT_WRIST.value),
        (mp_pose.PoseLandmark.LEFT_HIP.value, mp_pose.PoseLandmark.LEFT_KNEE.value),
        (mp_pose.PoseLandmark.LEFT_KNEE.value, mp_pose.PoseLandmark.LEFT_ANKLE.value),
        (mp_pose.PoseLandmark.RIGHT_HIP.value, mp_pose.PoseLandmark.RIGHT_KNEE.value),
        (mp_pose.PoseLandmark.RIGHT_KNEE.value, mp_pose.PoseLandmark.RIGHT_ANKLE.value),
    ]
    edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()
    data = Data(x=x, edge_index=edge_index, y=torch.tensor([label], dtype=torch.long))
    return data

# %%
dataset_path = "yoga-posture-dataset"  
output_csv = "yoga_keypoints2.csv"

# %%
def normalize_keypoints(keypoints):
    kps = np.array([(kp.x, kp.y, kp.z, kp.visibility) for kp in keypoints])
    neck = kps[mp_pose.PoseLandmark.NOSE.value][:3]  
    left_hip = kps[mp_pose.PoseLandmark.LEFT_HIP.value][:3]
    right_hip = kps[mp_pose.PoseLandmark.RIGHT_HIP.value][:3]
    mid_hip = (left_hip + right_hip) / 2
    torso_length = np.linalg.norm(neck - mid_hip)
    if torso_length < 1e-6:  
        return None
    normalized_kps = kps.copy()
    normalized_kps[:, :3] = normalized_kps[:, :3] / torso_length
    
    return normalized_kps.flatten().tolist()
columns = ["image_name", "class_label"]
for i in range(33): 
    columns += [f"kp{i}_x", f"kp{i}_y", f"kp{i}_z", f"kp{i}_vis"]  
data = []
class_folders = sorted(os.listdir(dataset_path))
total_classes = len(class_folders)
for class_idx, class_name in enumerate(class_folders):
    class_path = os.path.join(dataset_path, class_name)
    if not os.path.isdir(class_path):
        continue
    print(f"Processing class {class_idx + 1}/{total_classes}: {class_name}...")
    image_files = sorted(os.listdir(class_path))
    total_images = len(image_files)
    for img_idx, img_name in enumerate(image_files):
        img_path = os.path.join(class_path, img_name)
        image = cv2.imread(img_path)
        if image is None:
            print(f"  Skipping unreadable image: {img_name}")
            continue
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)
        if results.pose_landmarks:
            normalized_kps = normalize_keypoints(results.pose_landmarks.landmark)
            if normalized_kps:
                data.append([img_name, class_name] + normalized_kps)
            else:
                print(f"  Could not normalize keypoints for {img_name}")
        if (img_idx + 1) % 10 == 0:
            print(f"  Processed {img_idx + 1}/{total_images} images in {class_name}")
# Out:
# Processing class 1/48: Adho Mukha Svanasana...
#   Processed 10/74 images in Adho Mukha Svanasana
#   Processed 20/74 images in Adho Mukha Svanasana
#   Processed 30/74 images in Adho Mukha Svanasana
#   Processed 40/74 images in Adho Mukha Svanasana
#   Processed 50/74 images in Adho Mukha Svanasana
#   Processed 60/74 images in Adho Mukha Svanasana
#   Processed 70/74 images in Adho Mukha Svanasana
# Processing class 2/48: Adho Mukha Vrksasana...
#   Processed 10/65 images in Adho Mukha Vrksasana
#   Processed 20/65 images in Adho Mukha Vrksasana
#   Processed 30/65 images in Adho Mukha Vrksasana
#   Processed 40/65 images in Adho Mukha Vrksasana
#   Processed 50/65 images in Adho Mukha Vrksasana
#   Processed 60/65 images in Adho Mukha Vrksasana
# Processing class 3/48: Alanasana...
#   Processed 10/18 images in Alanasana
# Processing class 4/48: Anjaneyasana...
#   Processed 10/71 images in Anjaneyasana
#   Processed 20/71 images in Anjaneyasana
#   Processed 30/71 images in Anjaneyasana
#   Processed 40/71 images in Anjaneyasana
#   Processed 50/71 images in Anjaneyasana
#   Processed 60/71 images in Anjaneyasana
#   Processed 70/71 images in Anjaneyasana
# Processing class 5/48: Ardha Chandrasana...
#   Processed 10/59 images in Ardha Chandrasana
#   Processed 20/59 images in Ardha Chandrasana
#   Processed 30/59 images in Ardha Chandrasana
#   Processed 40/59 images in Ardha Chandrasana
#   Processed 50/59 images in Ardha Chandrasana
# Processing class 6/48: Ardha Matsyendrasana...
#   Processed 10/96 images in Ardha Matsyendrasana
#   Processed 20/96 images in Ardha Matsyendrasana
#   Processed 30/96 images in Ardha Matsyendrasana
#   Processed 40/96 images in Ardha Matsyendrasana
#   Processed 50/96 images in Ardha Matsyendrasana
#   Processed 60/96 images in Ardha Matsyendrasana
#   Processed 70/96 images in Ardha Matsyendrasana
#   Processed 80/96 images in Ardha Matsyendrasana
#   Processed 90/96 images in Ardha Matsyendrasana
# Processing class 7/48: Ardha Navasana...
#   Processed 10/13 images in Ardha Navasana
# Processing class 8/48: Ardha Pincha Mayurasana...
#   Processed 10/54 images in Ardha Pincha Mayurasana
#   Processed 20/54 images in Ardha Pincha Mayurasana
#   Processed 30/54 images in Ardha Pincha Mayurasana
#   Processed 40/54 images in Ardha Pincha Mayurasana
#   Processed 50/54 images in Ardha Pincha Mayurasana
# Processing class 9/48: Ashta Chandrasana...
#   Processed 10/12 images in Ashta Chandrasana
# Processing class 10/48: Baddha Konasana...
#   Processed 10/81 images in Baddha Konasana
#   Processed 20/81 images in Baddha Konasana
#   Processed 30/81 images in Baddha Konasana
#   Processed 40/81 images in Baddha Konasana
#   Processed 50/81 images in Baddha Konasana
#   Processed 60/81 images in Baddha Konasana
#   Processed 70/81 images in Baddha Konasana
#   Processed 80/81 images in Baddha Konasana
# Processing class 11/48: Bakasana...
#   Processed 10/84 images in Bakasana
#   Processed 20/84 images in Bakasana
#   Processed 30/84 images in Bakasana
#   Processed 40/84 images in Bakasana
#   Processed 50/84 images in Bakasana
#   Processed 60/84 images in Bakasana
#   Processed 70/84 images in Bakasana
#   Processed 80/84 images in Bakasana
# Processing class 12/48: Balasana...
#   Processed 10/79 images in Balasana
#   Processed 20/79 images in Balasana
#   Processed 30/79 images in Balasana
#   Processed 40/79 images in Balasana
#   Processed 50/79 images in Balasana
#   Processed 60/79 images in Balasana
#   Processed 70/79 images in Balasana
# Processing class 13/48: Bitilasana...
#   Processed 10/94 images in Bitilasana
#   Processed 20/94 images in Bitilasana
#   Processed 30/94 images in Bitilasana
#   Processed 40/94 images in Bitilasana
#   Processed 50/94 images in Bitilasana
#   Processed 60/94 images in Bitilasana
#   Processed 70/94 images in Bitilasana
#   Processed 80/94 images in Bitilasana
#   Processed 90/94 images in Bitilasana
# Processing class 14/48: Camatkarasana...
#   Processed 10/62 images in Camatkarasana
#   Processed 20/62 images in Camatkarasana
#   Processed 30/62 images in Camatkarasana
#   Processed 40/62 images in Camatkarasana
#   Processed 50/62 images in Camatkarasana
#   Processed 60/62 images in Camatkarasana
# Processing class 15/48: Dhanurasana...
#   Processed 10/54 images in Dhanurasana
#   Processed 20/54 images in Dhanurasana
#   Processed 30/54 images in Dhanurasana
#   Processed 40/54 images in Dhanurasana
#   Processed 50/54 images in Dhanurasana
# Processing class 16/48: Eka Pada Rajakapotasana...
#   Processed 10/53 images in Eka Pada Rajakapotasana
#   Processed 20/53 images in Eka Pada Rajakapotasana
#   Processed 30/53 images in Eka Pada Rajakapotasana
#   Processed 40/53 images in Eka Pada Rajakapotasana
#   Processed 50/53 images in Eka Pada Rajakapotasana
# Processing class 17/48: Garudasana...
#   Processed 10/85 images in Garudasana
#   Processed 20/85 images in Garudasana
#   Processed 30/85 images in Garudasana
#   Processed 40/85 images in Garudasana
#   Processed 50/85 images in Garudasana
#   Processed 60/85 images in Garudasana
#   Processed 70/85 images in Garudasana
#   Processed 80/85 images in Garudasana
# Processing class 18/48: Halasana...
#   Processed 10/71 images in Halasana
#   Processed 20/71 images in Halasana
#   Processed 30/71 images in Halasana
#   Processed 40/71 images in Halasana
#   Processed 50/71 images in Halasana
#   Processed 60/71 images in Halasana
#   Processed 70/71 images in Halasana
# Processing class 19/48: Hanumanasana...
#   Processed 10/41 images in Hanumanasana
#   Processed 20/41 images in Hanumanasana
#   Processed 30/41 images in Hanumanasana
#   Processed 40/41 images in Hanumanasana
# Processing class 20/48: Malasana...
#   Processed 10/73 images in Malasana
#   Processed 20/73 images in Malasana
#   Processed 30/73 images in Malasana
#   Processed 40/73 images in Malasana
#   Processed 50/73 images in Malasana
#   Processed 60/73 images in Malasana
#   Processed 70/73 images in Malasana
# Processing class 21/48: Marjaryasana...
#   Processed 10/56 images in Marjaryasana
#   Processed 20/56 images in Marjaryasana
#   Processed 30/56 images in Marjaryasana
#   Processed 40/56 images in Marjaryasana
#   Processed 50/56 images in Marjaryasana
# Processing class 22/48: Navasana...
#   Processed 10/18 images in Navasana
# Processing class 23/48: Padmasana...
#   Processed 10/77 images in Padmasana
#   Processed 20/77 images in Padmasana
#   Processed 30/77 images in Padmasana
#   Processed 40/77 images in Padmasana
#   Processed 50/77 images in Padmasana
#   Processed 60/77 images in Padmasana
#   Processed 70/77 images in Padmasana
# Processing class 24/48: Parsva Virabhadrasana...
#   Processed 10/14 images in Parsva Virabhadrasana
# Processing class 25/48: Parsvottanasana...
#   Processed 10/43 images in Parsvottanasana
#   Processed 20/43 images in Parsvottanasana
#   Processed 30/43 images in Parsvottanasana
#   Processed 40/43 images in Parsvottanasana
# Processing class 26/48: Paschimottanasana...
#   Processed 10/62 images in Paschimottanasana
#   Processed 20/62 images in Paschimottanasana
#   Processed 30/62 images in Paschimottanasana
#   Processed 40/62 images in Paschimottanasana
#   Processed 50/62 images in Paschimottanasana
#   Processed 60/62 images in Paschimottanasana
# Processing class 27/48: Phalakasana...
#   Processed 10/66 images in Phalakasana
#   Processed 20/66 images in Phalakasana
#   Processed 30/66 images in Phalakasana
#   Processed 40/66 images in Phalakasana
#   Processed 50/66 images in Phalakasana
#   Processed 60/66 images in Phalakasana
# Processing class 28/48: Pincha Mayurasana...
#   Processed 10/43 images in Pincha Mayurasana
#   Processed 20/43 images in Pincha Mayurasana
#   Processed 30/43 images in Pincha Mayurasana
#   Processed 40/43 images in Pincha Mayurasana
# Processing class 30/48: Salamba Bhujangasana...
#   Processed 10/62 images in Salamba Bhujangasana
#   Processed 20/62 images in Salamba Bhujangasana
#   Processed 30/62 images in Salamba Bhujangasana
#   Processed 40/62 images in Salamba Bhujangasana
#   Processed 50/62 images in Salamba Bhujangasana
#   Processed 60/62 images in Salamba Bhujangasana
# Processing class 31/48: Salamba Sarvangasana...
#   Processed 10/73 images in Salamba Sarvangasana
#   Processed 20/73 images in Salamba Sarvangasana
#   Processed 30/73 images in Salamba Sarvangasana
#   Processed 40/73 images in Salamba Sarvangasana
#   Processed 50/73 images in Salamba Sarvangasana
#   Processed 60/73 images in Salamba Sarvangasana
#   Processed 70/73 images in Salamba Sarvangasana
# Processing class 32/48: Setu Bandha Sarvangasana...
#   Processed 10/66 images in Setu Bandha Sarvangasana
#   Processed 20/66 images in Setu Bandha Sarvangasana
#   Processed 30/66 images in Setu Bandha Sarvangasana
#   Processed 40/66 images in Setu Bandha Sarvangasana
#   Processed 50/66 images in Setu Bandha Sarvangasana
#   Processed 60/66 images in Setu Bandha Sarvangasana
# Processing class 33/48: Sivasana...
#   Processed 10/20 images in Sivasana
#   Processed 20/20 images in Sivasana
# Processing class 34/48: Supta Kapotasana...
#   Processed 10/13 images in Supta Kapotasana
# Processing class 35/48: Trikonasana...
#   Processed 10/23 images in Trikonasana
#   Processed 20/23 images in Trikonasana
# Processing class 36/48: Upavistha Konasana...
#   Processed 10/17 images in Upavistha Konasana
# Processing class 37/48: Urdhva Dhanurasana...
#   Processed 10/74 images in Urdhva Dhanurasana
#   Processed 20/74 images in Urdhva Dhanurasana
#   Processed 30/74 images in Urdhva Dhanurasana
#   Processed 40/74 images in Urdhva Dhanurasana
#   Processed 50/74 images in Urdhva Dhanurasana
#   Processed 60/74 images in Urdhva Dhanurasana
#   Processed 70/74 images in Urdhva Dhanurasana
# Processing class 38/48: Urdhva Mukha Svsnssana...
#   Processed 10/69 images in Urdhva Mukha Svsnssana
#   Processed 20/69 images in Urdhva Mukha Svsnssana
#   Processed 30/69 images in Urdhva Mukha Svsnssana
#   Processed 40/69 images in Urdhva Mukha Svsnssana
#   Processed 50/69 images in Urdhva Mukha Svsnssana
#   Processed 60/69 images in Urdhva Mukha Svsnssana
# Processing class 39/48: Ustrasana...
#   Processed 10/96 images in Ustrasana
#   Processed 20/96 images in Ustrasana
#   Processed 30/96 images in Ustrasana
#   Processed 40/96 images in Ustrasana
#   Processed 50/96 images in Ustrasana
#   Processed 60/96 images in Ustrasana
#   Processed 70/96 images in Ustrasana
#   Processed 80/96 images in Ustrasana
#   Processed 90/96 images in Ustrasana
# Processing class 40/48: Utkatasana...
#   Processed 10/81 images in Utkatasana
#   Processed 20/81 images in Utkatasana
#   Processed 30/81 images in Utkatasana
#   Processed 40/81 images in Utkatasana
#   Processed 50/81 images in Utkatasana
#   Processed 60/81 images in Utkatasana
#   Processed 70/81 images in Utkatasana
#   Processed 80/81 images in Utkatasana
# Processing class 41/48: Uttanasana...
#   Processed 10/71 images in Uttanasana
#   Processed 20/71 images in Uttanasana
#   Processed 30/71 images in Uttanasana
#   Processed 40/71 images in Uttanasana
#   Processed 50/71 images in Uttanasana
#   Processed 60/71 images in Uttanasana
#   Processed 70/71 images in Uttanasana
# Processing class 42/48: Utthita Hasta Padangusthasana...
#   Processed 10/64 images in Utthita Hasta Padangusthasana
#   Processed 20/64 images in Utthita Hasta Padangusthasana
#   Processed 30/64 images in Utthita Hasta Padangusthasana
#   Processed 40/64 images in Utthita Hasta Padangusthasana
#   Processed 50/64 images in Utthita Hasta Padangusthasana
#   Processed 60/64 images in Utthita Hasta Padangusthasana
# Processing class 43/48: Utthita Parsvakonasana...
#   Processed 10/69 images in Utthita Parsvakonasana
#   Processed 20/69 images in Utthita Parsvakonasana
#   Processed 30/69 images in Utthita Parsvakonasana
#   Processed 40/69 images in Utthita Parsvakonasana
#   Processed 50/69 images in Utthita Parsvakonasana
#   Processed 60/69 images in Utthita Parsvakonasana
# Processing class 44/48: Vasisthasana...
#   Processed 10/80 images in Vasisthasana
#   Processed 20/80 images in Vasisthasana
#   Processed 30/80 images in Vasisthasana
#   Processed 40/80 images in Vasisthasana
#   Processed 50/80 images in Vasisthasana
#   Processed 60/80 images in Vasisthasana
#   Processed 70/80 images in Vasisthasana
#   Processed 80/80 images in Vasisthasana
# Processing class 45/48: Virabhadrasana One...
#   Processed 10/64 images in Virabhadrasana One
#   Processed 20/64 images in Virabhadrasana One
#   Processed 30/64 images in Virabhadrasana One
#   Processed 40/64 images in Virabhadrasana One
#   Processed 50/64 images in Virabhadrasana One
#   Skipping unreadable image: File56.gif
#   Processed 60/64 images in Virabhadrasana One
# Processing class 46/48: Virabhadrasana Three...
#   Processed 10/69 images in Virabhadrasana Three
#   Processed 20/69 images in Virabhadrasana Three
#   Processed 30/69 images in Virabhadrasana Three
#   Processed 40/69 images in Virabhadrasana Three
#   Processed 50/69 images in Virabhadrasana Three
#   Processed 60/69 images in Virabhadrasana Three
# Processing class 47/48: Virabhadrasana Two...
#   Processed 10/61 images in Virabhadrasana Two
#   Processed 20/61 images in Virabhadrasana Two
#   Processed 30/61 images in Virabhadrasana Two
#   Processed 40/61 images in Virabhadrasana Two
#   Processed 50/61 images in Virabhadrasana Two
#   Skipping unreadable image: File56.gif
#   Processed 60/61 images in Virabhadrasana Two
# Processing class 48/48: Vrksasana...
#   Processed 10/68 images in Vrksasana
#   Processed 20/68 images in Vrksasana
#   Processed 30/68 images in Vrksasana
#   Processed 40/68 images in Vrksasana
#   Processed 50/68 images in Vrksasana
#   Processed 60/68 images in Vrksasana

# %%
df = pd.DataFrame(data, columns=columns)
df.to_csv(output_csv, index=False)
print(f"\nNormalized keypoints saved to {output_csv}")
# Out:
# Normalized keypoints saved to yoga_keypoints2.csv

# %%
def calculate_angle(a, b, c):
    a, b, c = np.array(a[:2]), np.array(b[:2]), np.array(c[:2])  # Ignore z and visibility
    ba = a - b
    bc = c - b
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))  # Clip for numerical stability
    return np.degrees(angle)

# %%
# Load the normalized keypoints CSV
df = pd.read_csv(output_csv)

# Angle definitions (using MediaPipe landmark indices)
angle_definitions = {
    "left_elbow": (mp_pose.PoseLandmark.LEFT_SHOULDER.value, 
                   mp_pose.PoseLandmark.LEFT_ELBOW.value, 
                   mp_pose.PoseLandmark.LEFT_WRIST.value),
    "right_elbow": (mp_pose.PoseLandmark.RIGHT_SHOULDER.value, 
                    mp_pose.PoseLandmark.RIGHT_ELBOW.value, 
                    mp_pose.PoseLandmark.RIGHT_WRIST.value),
    "left_knee": (mp_pose.PoseLandmark.LEFT_HIP.value, 
                  mp_pose.PoseLandmark.LEFT_KNEE.value, 
                  mp_pose.PoseLandmark.LEFT_ANKLE.value),
    "right_knee": (mp_pose.PoseLandmark.RIGHT_HIP.value, 
                   mp_pose.PoseLandmark.RIGHT_KNEE.value, 
                   mp_pose.PoseLandmark.RIGHT_ANKLE.value),
    "left_hip": (mp_pose.PoseLandmark.LEFT_SHOULDER.value, 
                 mp_pose.PoseLandmark.LEFT_HIP.value, 
                 mp_pose.PoseLandmark.LEFT_KNEE.value),
    "right_hip": (mp_pose.PoseLandmark.RIGHT_SHOULDER.value, 
                  mp_pose.PoseLandmark.RIGHT_HIP.value, 
                  mp_pose.PoseLandmark.RIGHT_KNEE.value),
    "left_shoulder": (mp_pose.PoseLandmark.LEFT_ELBOW.value, 
                      mp_pose.PoseLandmark.LEFT_SHOULDER.value, 
                      mp_pose.PoseLandmark.LEFT_HIP.value),
    "right_shoulder": (mp_pose.PoseLandmark.RIGHT_ELBOW.value, 
                       mp_pose.PoseLandmark.RIGHT_SHOULDER.value, 
                       mp_pose.PoseLandmark.RIGHT_HIP.value)
}

angle_features = []

for _, row in df.iterrows():
    keypoints = []
    for i in range(33):  
        x = row[f'kp{i}_x']
        y = row[f'kp{i}_y']
        z = row[f'kp{i}_z']
        vis = row[f'kp{i}_vis']
        keypoints.append((x, y, z, vis))
    
    angles = {}
    for name, (a_idx, b_idx, c_idx) in angle_definitions.items():
        try:
            a = keypoints[a_idx]
            b = keypoints[b_idx]
            c = keypoints[c_idx]
            
            if a[3] > 0.5 and b[3] > 0.5 and c[3] > 0.5:
                angles[name] = calculate_angle(a, b, c)
            else:
                angles[name] = None  
        except (IndexError, KeyError) as e:
            print(f"Error calculating {name} angle: {e}")
            angles[name] = None
    
    angle_features.append(angles)

angles_df = pd.DataFrame(angle_features)
df = pd.concat([df, angles_df], axis=1)

updated_csv_path = output_csv.replace(".csv", "_with_angles.csv")
df.to_csv(updated_csv_path, index=False)
print(f"Updated CSV with angles saved to: {updated_csv_path}")
# Out:
# Updated CSV with angles saved to: yoga_keypoints2_with_angles.csv
